# %%
import pandas
file = pandas.read_csv("C:\\Users\\b1070\\Desktop\\AI100\\data\\application_train.csv")

# %% [markdown]
# 資料的 row 數以及 column 數

# %%
rows = file.shape[0]
columns = file.shape[1]
print("row: {0}\ncolumns: {1}".format(rows, columns))
# Out:
# row: 307511
# columns: 122

# %% [markdown]
# 列出所有欄位

# %%
file.head(rows)
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 218731      353408       0    Revolving loans           F            N
# 138241      260313       0    Revolving loans           M            Y
# 225783      361516       0    Revolving loans           F            N
# 9580        111135       0    Revolving loans           M            Y
# 296899      443975       0    Revolving loans           F            Y
# 296896      443971       0    Revolving loans           M            Y
# 9583        111138       0    Revolving loans           M            N
# 9585        111140       0    Revolving loans           F            N
# 73854       185654       0    Revolving loans           M            Y
# 73852       185652       0    Revolving loans           F            Y
# 225792      361526       0    Revolving loans           M            N
# 9592        111149       0    Revolving loans           M            N
# ...

# %% [markdown]
# 擷取部分資料

# %%
file[['CODE_GENDER','FLAG_OWN_CAR']][0:5]
# Out:
#        CODE_GENDER FLAG_OWN_CAR
# 218731           F            N
# 138241           M            Y
# 225783           F            N
# 9580             M            Y
# 296899           F            Y
